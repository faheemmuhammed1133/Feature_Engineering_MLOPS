# %%
import pandas as pd 
import matplotlib.pyplot as plt 

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import RobustScaler

# %%
x , y = fetch_california_housing(return_X_y=True,as_frame=True)

# %%
x.describe().round(2)
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# count  20640.00  20640.00  20640.00   20640.00    20640.00  20640.00
# mean       3.87     28.64      5.43       1.10     1425.48      3.07
# std        1.90     12.59      2.47       0.47     1132.46     10.39
# min        0.50      1.00      0.85       0.33        3.00      0.69
# 25%        2.56     18.00      4.44       1.01      787.00      2.43
# 50%        3.53     29.00      5.23       1.05     1166.00      2.82
# 75%        4.74     37.00      6.05       1.10     1725.00      3.28
# max       15.00     52.00    141.91      34.07    35682.00   1243.33
#
#        Latitude  Longitude
# count  20640.00   20640.00
# mean      35.63    -119.57
# std        2.14       2.00
# min       32.54    -124.35
# 25%       33.93    -121.80
# 50%       34.26    -118.49
# 75%       37.71    -118.01
# max       41.95    -114.31

# %%
x_train,x_test,y_train,y_test= train_test_split(
   x,y,random_state=0
)

# %%
scaler = RobustScaler().set_output(transform='pandas')

scaler.fit(x_train)

x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled.head()
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 19226  1.720272 -0.526316  1.703619   0.944027    0.808307  0.308126
# 14549  1.103066 -0.578947  0.820205   0.575712   -0.660277 -0.664448
# 9093  -0.154737 -0.526316 -0.016675   1.786132   -0.908413  0.168387
# 12213  1.579318 -0.842105  0.746026  -0.515685   -1.115016  0.045293
# 12765 -0.474119 -0.421053 -0.502771  -0.126519    0.604899 -0.539965
#
#        Latitude  Longitude
# 19226  1.113757  -1.102632
# 14549 -0.343915   0.328947
# 9093   0.113757   0.057895
# 12213 -0.195767   0.344737
# 12765  1.156085  -0.768421

# %%
x_train_scaled.describe().head().round(2)
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# count  15480.00  15480.00  15480.00   15480.00    15480.00  15480.00
# mean       0.15     -0.02      0.12       0.50        0.28      0.26
# std        0.87      0.66      1.58       5.23        1.22      7.79
# min       -1.40     -1.47     -2.74      -7.59       -1.24     -2.42
# 25%       -0.45     -0.58     -0.49      -0.45       -0.41     -0.46
#
#        Latitude  Longitude
# count  15480.00   15480.00
# mean       0.36      -0.28
# std        0.57       0.53
# min       -0.45      -1.54
# 25%       -0.08      -0.87

# %%
x_train.hist(bins=20 , figsize=(10,10))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x_train_scaled.hist(bins=20 , figsize=(10,10))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
