# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

df= pd.read_csv("/Users/muhammedfaheem/Desktop/AI_DS/Feature Engineering/Datasets/loan_default_20features.csv")
print(df.shape)
df.head(5)
# Out:
# (1000, 21)
#    customer_id  credit_score  annual_income  debt_to_income_ratio  \
# 0            3           659        28200.0                 0.542
# 1          880           607        40800.0                 0.313
# 2           58           584        96600.0                 0.375
# 3          497           757        85600.0                 0.330
# 4          612           659        62600.0                 0.416
#
#    employment_years  num_late_payments_12m  num_credit_lines  loan_amount  \
# 0              10.1                      1                 4       7800.0
# 1               5.0                      0                13      12500.0
# 2               2.3                      1                 6       5500.0
# 3              15.6                      0                 9       6400.0
# 4               4.4                      0                 3      13300.0
#
#    age  has_mortgage  ...  monthly_expenses  savings_balance  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score

work = df.copy()
work["region_enc"] = LabelEncoder().fit_transform(work["region"])
work["nois3_enc"] = LabelEncoder().fit_transform(work["random_noise_3"])

# feature_cols = [
#    "credit_score","","",
# ]

# %%
from sklearn.inspection import permutation_importance

perm_result = permutation_importance(
   model,X_test,y_test,n_repeats=15,random_state=42,scoring="roc_auc_"
)

perm_importance = pd.Series(perm_result.importances_mean, index=feature_cols).sort_values(ascending=False)

fig, ax = plt.subplot(figsize=(8,6))
perm_importance.sort_values().plot(kind="barh",ax=ax,color="#c13584")
ax.axvline
