# %%
import pandas as pd 
import matplotlib.pyplot as plt 


from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler

# %%
x, y = fetch_california_housing(return_X_y=True,as_frame=True)

# %%
x.describe().round(2)
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# count  20640.00  20640.00  20640.00   20640.00    20640.00  20640.00
# mean       3.87     28.64      5.43       1.10     1425.48      3.07
# std        1.90     12.59      2.47       0.47     1132.46     10.39
# min        0.50      1.00      0.85       0.33        3.00      0.69
# 25%        2.56     18.00      4.44       1.01      787.00      2.43
# 50%        3.53     29.00      5.23       1.05     1166.00      2.82
# 75%        4.74     37.00      6.05       1.10     1725.00      3.28
# max       15.00     52.00    141.91      34.07    35682.00   1243.33
#
#        Latitude  Longitude
# count  20640.00   20640.00
# mean      35.63    -119.57
# std        2.14       2.00
# min       32.54    -124.35
# 25%       33.93    -121.80
# 50%       34.26    -118.49
# 75%       37.71    -118.01
# max       41.95    -114.31

# %%
x_train,x_test,y_train,y_test= train_test_split(
   x,y,random_state=0
)

# %%
scaler = StandardScaler().set_output(transform='pandas')

scaler.fit(x_train)

x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled.head()
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 19226  1.808122 -0.764262  0.998207   0.084854    0.436631  0.006579
# 14549  1.097891 -0.843631  0.440005   0.014431   -0.768275 -0.118332
# 9093  -0.349490 -0.764262 -0.088795   0.245869   -0.971859 -0.011368
# 12213  1.645924 -1.240475  0.393134  -0.194249   -1.141367 -0.027177
# 12765 -0.717009 -0.605525 -0.395943  -0.119839    0.269744 -0.102345
#
#        Latitude  Longitude
# 19226  1.324919  -1.552206
# 14549 -1.252070   1.159540
# 9093  -0.442961   0.646103
# 12213 -0.990162   1.189449
# 12765  1.399750  -0.919133

# %%
x_train.hist(bins=20 , figsize=(10,10))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x_train_scaled.hist(bins=20 , figsize=(10,10))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
