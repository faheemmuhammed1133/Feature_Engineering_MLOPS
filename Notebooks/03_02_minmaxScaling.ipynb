# %%
import pandas as pd 
import matplotlib.pyplot as plt 

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import MinMaxScaler

# %%
x , y = fetch_california_housing(return_X_y=True,as_frame=True)

# %%
x.describe().round(2)
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# count  20640.00  20640.00  20640.00   20640.00    20640.00  20640.00
# mean       3.87     28.64      5.43       1.10     1425.48      3.07
# std        1.90     12.59      2.47       0.47     1132.46     10.39
# min        0.50      1.00      0.85       0.33        3.00      0.69
# 25%        2.56     18.00      4.44       1.01      787.00      2.43
# 50%        3.53     29.00      5.23       1.05     1166.00      2.82
# 75%        4.74     37.00      6.05       1.10     1725.00      3.28
# max       15.00     52.00    141.91      34.07    35682.00   1243.33
#
#        Latitude  Longitude
# count  20640.00   20640.00
# mean      35.63    -119.57
# std        2.14       2.00
# min       32.54    -124.35
# 25%       33.93    -121.80
# 50%       34.26    -118.49
# 75%       37.71    -118.01
# max       41.95    -114.31

# %%
x_train,x_test,y_train,y_test= train_test_split(
   x,y,random_state=0
)

# %%
scaler = MinMaxScaler().set_output(transform='pandas')

scaler.fit(x_train)

x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
scaler.data_range_
# Out:
# array([1.45002000e+01, 5.10000000e+01, 1.41062937e+02, 3.37333333e+01,
#        3.56790000e+04, 5.98964286e+02, 9.41000000e+00, 1.00400000e+01])

# %%
x_train_scaled.head()
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 19226  0.468987  0.352941  0.050442   0.023842    0.053897  0.003893
# 14549  0.376188  0.333333  0.040416   0.022813    0.015247  0.002506
# 9093   0.187073  0.352941  0.030918   0.026195    0.008717  0.003693
# 12213  0.447794  0.235294  0.039574   0.019763    0.003279  0.003518
# 12765  0.139053  0.392157  0.025401   0.020850    0.048544  0.002684
#
#        Latitude  Longitude
# 19226  0.629118   0.166335
# 14549  0.043571   0.708167
# 9093   0.227418   0.605578
# 12213  0.103082   0.714143
# 12765  0.646121   0.292829

# %%
x_train.hist(bins=20 , figsize=(10,10))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x_train_scaled.hist(bins=20 , figsize=(10,10))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
